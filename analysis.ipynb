# %% [markdown]
# <a href="https://colab.research.google.com/github/JayasreeThyadi/SIH23-AYUR-BHARATH/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Install necessary libraries if not already installed
# !pip install pandas openpyxl

import pandas as pd
from google.colab import files

# Upload the Excel files to Colab
data = files.upload()
# Out:
# ...
#      <input type="file" id="files-82a270f1-22ed-46ac-b9c4-0c64e4d99975" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82a270f1-22ed-46ac-b9c4-0c64e4d99975">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filename='2021.xlsx'
a = pd.read_excel(filename)
filename='2022.xlsx'
b = pd.read_excel(filename)
filename='2023.xlsx'
c = pd.read_excel(filename)

# %%
a.head()
# Out:
#   LOCATION  YEAR MONTH  RAINFALL  DEPTH  AVAILABLE DREDGER  CAPACITY  \
# 0   COCHIN  2021  JAN         22   2.90                  8      6500
# 1   COCHIN  2021  JAN         22   2.90                 19      5500
# 2   COCHIN  2021  JAN         22   2.90                 15      4500
# 3   COCHIN  2021   FEB        27   2.85                 15      4500
# 4   COCHIN  2021   FEB        27   2.85                 19      5500
#
#    RAINFALL<300  RAINFALL>300  DECISION  DREDGER USED  DREDGER AMOUNT
# 0             1             0         8            15      1315497.55
# 1             0             0         8            15      1315497.55
# 2             1             0         8            15      1315497.55
# 3             1             0        20            15      1300574.55
# 4             0             0        20            15      1300574.55

# %%
b.head()
# Out:
#   LOCATION  YEAR MONTH  RAINFALL  DEPTH  AVAILABLE DREDGER  CAPACITY  \
# 0   COCHIN  2022  JAN         25   3.00                 11      4500
# 1   COCHIN  2022  JAN         25   3.00                 20      5500
# 2   COCHIN  2022  JAN         25   3.00                 19      5500
# 3   COCHIN  2022   FEB        31   2.95                  8      6500
# 4   COCHIN  2022   FEB        31   2.95                 19      5500
#
#    RAINFALL<300  RAINFALL>300  DECISION  DREDGER USED  DREDGER AMOUNT
# 0             1             0        20             8       1171587.0
# 1             1             0        20             8       1171587.0
# 2             0             0        20             8       1171587.0
# 3             1             0         8             8       1464101.0
# 4             0             0         8             8       1464101.0

# %%
c.head()
# Out:
#   LOCATION  YEAR MONTH  RAINFALL  DEPTH  AVAILABLE DREDGER  CAPACITY  \
# 0   COCHIN  2023  JAN         25   3.00                  8      6500
# 1   COCHIN  2023  JAN         25   3.00                 20      5500
# 2   COCHIN  2023   FEB        30   2.95                 19      5500
# 3   COCHIN  2023   FEB        30   2.95                 11      6500
# 4   COCHIN  2023   MAR        60   2.70                 20      5500
#
#    RAINFALL<300  RAINFALL>300  DECISION  DREDGER USED  DREDGER AMOUNT
# 0             1             0         8            20         1166659
# 1             0             0         8            20         1166659
# 2             0             0        11            20         1060334
# 3             1             0        11            20         1060334
# 4             1             0        15             8         1175979

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='MONTH', y='RAINFALL', data=a, label='2021')
sns.lineplot(x='MONTH', y='RAINFALL', data=b, label='2022')
sns.lineplot(x='MONTH', y='RAINFALL', data=c, label='2023')
plt.title('Rainfall over Months (2021-2023)')
plt.xlabel('Month')
plt.ylabel('Rainfall (mm)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='MONTH', y='DEPTH', data=a, label='2021')
sns.lineplot(x='MONTH', y='DEPTH', data=b, label='2022')
sns.lineplot(x='MONTH', y='DEPTH', data=c, label='2023')
plt.title('Depth over Months (2021-2023)')
plt.xlabel('Month')
plt.ylabel('Depth (m)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='MONTH', y='DREDGER AMOUNT', data=a, label='2021')
sns.lineplot(x='MONTH', y='DREDGER AMOUNT', data=b, label='2022')
sns.lineplot(x='MONTH', y='DREDGER AMOUNT', data=c, label='2023')
plt.title('dredger amount over Months (2021-2023)')
plt.xlabel('Month')
plt.ylabel('dredger amount')
plt.legend()
plt.show()

# %%
mean_amounts = [a['DREDGER AMOUNT'].mean(), b['DREDGER AMOUNT'].mean(), c['DREDGER AMOUNT'].mean()]

# Dataset names for the x-axis
dataset_names = ['a', 'b', 'c']

# Plotting the bar graph
plt.bar(dataset_names, mean_amounts, color='skyblue')
plt.xlabel('Datasets')
plt.ylabel('Mean Dredger Amount')
plt.title('Mean Dredger Amount Across Datasets')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='MONTH', y='RAINFALL', data=a, label='Rainfall 2021')
plt.title('Rainfall over Months in 2021')
plt.xlabel('Month')
plt.ylabel('Rainfall (mm)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='MONTH', y='RAINFALL', data=b, label='Rainfall 2022')
plt.title('Rainfall over Months in 2022')
plt.xlabel('Month')
plt.ylabel('Rainfall (mm)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='MONTH', y='RAINFALL', data=c, label='Rainfall 2023')
plt.title('Rainfall over Months in 2023')
plt.xlabel('Month')
plt.ylabel('Rainfall (mm)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='MONTH', y='DEPTH',data=a, label='Depth 2021')
plt.title('Depth over Months in 2021')
plt.xlabel('Month')
plt.ylabel('Depth (m)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='MONTH', y='DEPTH',data=b, label='Depth 2022')
plt.title('Depth over Months in 2022')
plt.xlabel('Month')
plt.ylabel('Depth (m)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='MONTH', y='DEPTH',data=c, label='Depth 2023')
plt.title('Depth over Months in 2023')
plt.xlabel('Month')
plt.ylabel('Depth (m)')
plt.legend()
plt.show()

# %%
correlation_matrix = a[['RAINFALL', 'DEPTH']].corr()
print(correlation_matrix)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap: Rainfall vs Depth 2021')
plt.show()
# Out:
#           RAINFALL    DEPTH
# RAINFALL   1.00000 -0.93626
# DEPTH     -0.93626  1.00000

# %%
correlation_matrix = b[['RAINFALL', 'DEPTH']].corr()
print(correlation_matrix)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap: Rainfall vs Depth 2022')
plt.show()
# Out:
#           RAINFALL    DEPTH
# RAINFALL   1.00000 -0.96582
# DEPTH     -0.96582  1.00000

# %%
correlation_matrix = c[['RAINFALL', 'DEPTH']].corr()
print(correlation_matrix)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap: Rainfall vs Depth 2023')
plt.show()
# Out:
#           RAINFALL     DEPTH
# RAINFALL  1.000000 -0.781866
# DEPTH    -0.781866  1.000000

# %%
correlation_matrix = a[['RAINFALL', 'DREDGER AMOUNT']].corr()
print(correlation_matrix)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap: Rainfall vs dredger amount 2021')
plt.show()
# Out:
#                 RAINFALL  DREDGER AMOUNT
# RAINFALL        1.000000        0.309174
# DREDGER AMOUNT  0.309174        1.000000

# %%
correlation_matrix = b[['RAINFALL', 'DREDGER AMOUNT']].corr()
print(correlation_matrix)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap: Rainfall vs dredger amount 2022')
plt.show()
# Out:
#                 RAINFALL  DREDGER AMOUNT
# RAINFALL        1.000000        0.032479
# DREDGER AMOUNT  0.032479        1.000000

# %%
correlation_matrix = c[['RAINFALL', 'DREDGER AMOUNT']].corr()
print(correlation_matrix)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap: Rainfall vs dredger amount 2023')
plt.show()
# Out:
#                 RAINFALL  DREDGER AMOUNT
# RAINFALL        1.000000        0.020188
# DREDGER AMOUNT  0.020188        1.000000

# %%
correlation_matrix = a[['CAPACITY', 'DREDGER AMOUNT']].corr()
print(correlation_matrix)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap: capacity vs dredger amount 2021')
plt.show()
# Out:
#                 CAPACITY  DREDGER AMOUNT
# CAPACITY        1.000000       -0.231416
# DREDGER AMOUNT -0.231416        1.000000

# %%
correlation_matrix = b[['CAPACITY', 'DREDGER AMOUNT']].corr()
print(correlation_matrix)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap: capacity vs dredger amount 2022')
plt.show()
# Out:
#                 CAPACITY  DREDGER AMOUNT
# CAPACITY        1.000000        0.139347
# DREDGER AMOUNT  0.139347        1.000000

# %%
correlation_matrix = c[['CAPACITY', 'DREDGER AMOUNT']].corr()
print(correlation_matrix)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap: capacity vs dredger amount 2023')
plt.show()
# Out:
#                 CAPACITY  DREDGER AMOUNT
# CAPACITY        1.000000        0.012195
# DREDGER AMOUNT  0.012195        1.000000

# %%
#Load multiple Excel files into separate DataFrames
file_names = ["2021.xlsx", "2022.xlsx", "2023.xlsx"]  # Replace with your file names

dfs = {}  # Dictionary to store DataFrames

for file_name in file_names:
    df = pd.read_excel(file_name)
    dfs[file_name] = df

# Display the loaded data for each DataFrame
for file_name, df in dfs.items():
    print(f"Contents of {file_name}:")
    print(df)
    print("\n")
# Out:
# Contents of 2021.xlsx:
#     LOCATION  YEAR MONTH  RAINFALL  DEPTH  AVAILABLE DREDGER  CAPACITY  \
# 0     COCHIN  2021  JAN         22   2.90                  8      6500
# 1     COCHIN  2021  JAN         22   2.90                 19      5500
# 2     COCHIN  2021  JAN         22   2.90                 15      4500
# 3     COCHIN  2021   FEB        27   2.85                 15      4500
# 4     COCHIN  2021   FEB        27   2.85                 19      5500
# ..       ...   ...   ...       ...    ...                ...       ...
# 185   COCHIN  2021   NOV       169   2.65                 19      5500
# 186   COCHIN  2021   NOV       169   2.65                 11      4500
# 187   COCHIN  2021   DEC        56   2.67                  8      6500
# 188   COCHIN  2021   DEC        56   2.67                 15      7400
# 189   COCHIN  2021   DEC        56   2.67                 11      4500
#
#      RAINFALL<300  RAINFALL>300  DECISION  DREDGER USED  DREDGER AMOUNT
# ...

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-26-211b40d800e3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
